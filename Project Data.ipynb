# %%
import pandas as pd

# %%
dat = pd.read_csv('used_cars_data.csv')
dat.head()
# Out:
# C:\Users\hibar\AppData\Local\Temp\ipykernel_9688\2568599977.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   dat = pd.read_csv('used_cars_data.csv')
#                  vin back_legroom  bed bed_height bed_length        body_type  \
# 0  ZACNJABB5KPJ92081      35.1 in  NaN        NaN        NaN  SUV / Crossover
# 1  SALCJ2FX1LH858117      38.1 in  NaN        NaN        NaN  SUV / Crossover
# 2  JF1VA2M67G9829723      35.4 in  NaN        NaN        NaN            Sedan
# 3  SALRR2RV0L2433391      37.6 in  NaN        NaN        NaN  SUV / Crossover
# 4  SALCJ2FXXLH862327      38.1 in  NaN        NaN        NaN  SUV / Crossover
#
#   cabin      city  city_fuel_economy  combine_fuel_economy  ...  transmission  \
# 0   NaN   Bayamon                NaN                   NaN  ...             A
# 1   NaN  San Juan                NaN                   NaN  ...             A
# ...

# %%
na_counts = pd.DataFrame(dat.isna().sum())

# %%
na_counts = na_counts.reset_index()
na_counts
# Out:
#                    index        0
# 0                    vin        0
# 1           back_legroom   159269
# 2                    bed  2980472
# 3             bed_height  2570942
# 4             bed_length  2570942
# ..                   ...      ...
# 61          wheel_system   146732
# 62  wheel_system_display   146732
# 63             wheelbase   159269
# 64                 width   159269
# 65                  year        0
#
# [66 rows x 2 columns]

# %%
na_counts['cols'] = na_counts['index']

# %%
cols_remove = (na_counts.sort_values(by = 0, ascending = False)).head(9)

# %%
#removed columns with 2 million missing
for i in (list(cols_remove.cols)):
    dat = dat.drop(i, axis = 1)

# %%
cols_remove.cols
# Out:
# 60    vehicle_damage_category
# 9        combine_fuel_economy
# 30               is_certified
# 2                         bed
# 6                       cabin
# 33                  is_oemcpo
# 31                     is_cpo
# 3                  bed_height
# 4                  bed_length
# Name: cols, dtype: object

# %%
dat.isna().sum()
# Out:
# vin                           0
# back_legroom             159269
# body_type                 13543
# city                          0
# city_fuel_economy        491285
# daysonmarket                  0
# dealer_zip                    0
# description               77901
# engine_cylinders         100581
# engine_displacement      172386
# engine_type              100581
# exterior_color               26
# fleet                   1426595
# frame_damaged           1426595
# franchise_dealer              0
# franchise_make           572635
# front_legroom            159269
# fuel_tank_volume         159269
# fuel_type                 82724
# has_accidents           1426595
# height                   159269
# highway_fuel_economy     491285
# horsepower               172386
# interior_color              165
# isCab                   1426595
# is_new                        0
# latitude                      0
# length                   159269
# listed_date                   0
# ...

# %%
nonmissing_dat = dat.dropna()

# %%
nonmissing_dat.shape
# Out:
# (621616, 57)

# %%
data = nonmissing_dat.sample(n = 6000, random_state = 10)

# %%
#test = nonmissing_dat.sample(n = 3000, random_state = 20)

# %%
data.shape
# Out:
# (6000, 57)

# %%
data.price.isna().sum()
# Out:
# 0

# %%
data.to_csv('us_used_cars_final.csv', index = False)

# %%
data.dtypes
# Out:
# vin                      object
# back_legroom             object
# body_type                object
# city                     object
# city_fuel_economy       float64
# daysonmarket              int64
# dealer_zip               object
# description              object
# engine_cylinders         object
# engine_displacement     float64
# engine_type              object
# exterior_color           object
# fleet                    object
# frame_damaged            object
# franchise_dealer           bool
# franchise_make           object
# front_legroom            object
# fuel_tank_volume         object
# fuel_type                object
# has_accidents            object
# height                   object
# highway_fuel_economy    float64
# horsepower              float64
# interior_color           object
# isCab                    object
# is_new                     bool
# latitude                float64
# length                   object
# listed_date              object
# ...

# %%
data.head()
# Out:
#                        vin back_legroom        body_type          city  \
# 2653463  5LMCJ2C97HUL71203      36.8 in  SUV / Crossover        Devine
# 1912149  1FM5K8D87HGE07214      39.5 in  SUV / Crossover       Buffalo
# 1613127  1FMCU0GX6FUA14602      36.8 in  SUV / Crossover  Murfreesboro
# 2987274  WBA4W7C56JAB87837      33.7 in            Coupe    San Rafael
# 134975   SADCL2GX4KA397815      37.2 in  SUV / Crossover     Glen Cove
#
#          city_fuel_economy  daysonmarket dealer_zip  \
# 2653463               21.0            40      78016
# 1912149               16.0             9      55313
# 1613127               23.0            30      37129
# 2987274               21.0            45      94901
# 134975                22.0           319      11542
#
#                                                description engine_cylinders  \
# 2653463  *We have 19 sources of financing and second ch...               I4
# ...

# %%
data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 data.shape
#
# NameError: name 'data' is not defined
